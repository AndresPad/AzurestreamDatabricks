# %%
# TODO Recording: Expand the dataframe and show the columns in the data frame
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
auto_data = spark.sql('select * from default.automobile_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auto_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----------------+---------+---------+----------+------------+----------+------------+---------------+----------+------+-----+------+-----------+-----------+----------------+-----------+-----------+----+------+-----------------+----------+--------+--------+-----------+-----+
# symboling|normalized-losses|     make|fuel-type|aspiration|num-of-doors|body-style|drive-wheels|engine-location|wheel-base|length|width|height|curb-weight|engine-type|num-of-cylinders|engine-size|fuel-system|bore|stroke|compression-ratio|horsepower|peak-rpm|city-mpg|highway-mpg|price|
# ...

# %%
## TODO Recording: In the cell below

# Click on the arrow  next to the "make" to sort the data first in ascending order
# Click on the arrow next to the "make" again to sort data now in descending order
# Make sure you scroll horizontally to show all columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
display(auto_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
images = spark.read.format("image") \
              .load("dbfs:/FileStore/FlowerShow")

display(images)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
displayHTML("""
<h2>
  <b> <ins> What is Databricks? </ins> </b> 
</h2>
     
<p style = "color:green" >
    <i> Databricks is an enterprise software company founded by the creators of 
     <a href= https://spark.apache.org/docs/latest/ <b> Apache Spark</b>. </a> 
     <sup> [1] </sup> <br>
     
    Their products include <i> Delta Lake, MLflow </i> and  <i> Koalas,</i> open source projects that span data engineering,
        data science and machine learning.</p>

<p> Documentation <a href="https://docs.databricks.com/">here</a> </p>
""")
# Out:
# <h2>
#   <b> <ins> What is Databricks? </ins> </b>
# </h2>
#
# <p style = "color:green" >
#     <i> Databricks is an enterprise software company founded by the creators of
#      <a href= https://spark.apache.org/docs/latest/ <b> Apache Spark</b>. </a>
#      <sup> [1] </sup> <br>
#
#     Their products include <i> Delta Lake, MLflow </i> and  <i> Koalas,</i> open source projects that span data engineering,
#         data science and machine learning.</p>
#
# <p> Documentation <a href="https://docs.databricks.com/">here</a> </p>
