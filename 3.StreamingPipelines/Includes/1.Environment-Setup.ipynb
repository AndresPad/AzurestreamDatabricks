# %%
# %python
course_name = "Azurestream Databricks Streaming Environment Setup"

# %%
# %run "./2.Dataset-Mounts"
# Out:
# <p>Initialized environment variables & functions...</p>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <p>Datasets are already mounted to <b>/mnt/training</b> from <b>wasbs://training@dbtraineastus.blob.core.windows.net/</b></p>

# %%
# %run "./3.Create-User-DB"
# Out:
# <p>Created user-specific database: <b>anpadill_microsoft_com_db</b></p>
# <p>Using the database <b style="color:green">anpadill_microsoft_com_db</b>.</p>

# %%
# %run ./4.Streaming-Demo-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
displayHTML("<p>Azurestream Environment Setup - All done!</p>")
