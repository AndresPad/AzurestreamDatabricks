# %% [markdown]
# # <img src ='https://airsblobstorage.blob.core.windows.net/airstream/Asset 256.png' width="50px"> Streaming Concepts
#
# [link to tutorial](https://docs.microsoft.com/en-us/azure/databricks/scenarios/databricks-stream-from-eventhubs)

# %%
# %run "./Includes/1.Environment-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <p>Initialized environment variables & functions...</p>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <p>Datasets are already mounted to <b>/mnt/training</b> from <b>wasbs://training@dbtraineastus.blob.core.windows.net/</b></p>

# %%
# %python

event_hub_name = "spark-eh"
connection_string = dbutils.secrets.get(scope="akv-bck-scope", key="EventHubCnx-Azustream") + ";EntityPath=" + event_hub_name
  
print("Event Hub Connection String From Azure Key Vault: {}".format(connection_string))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Event Hub Connection String From Azure Key Vault: [REDACTED];EntityPath=spark-eh
# </div>
# <p>Created user-specific database: <b>anpadill_microsoft_com_db</b></p>
# <p>Using the database <b style="color:green">anpadill_microsoft_com_db</b>.</p>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# ...

# %%
# %python

ehWriteConf = {
  'eventhubs.connectionString' : connection_string
}

checkpointPath = userhome + "/event-hub/write-checkpoint"
dbutils.fs.rm(checkpointPath,True)
print(checkpointPath)

(activityStreamDF
  .writeStream
  .format("eventhubs")
  .options(**ehWriteConf)
  .option("checkpointLocation", checkpointPath)
  .start())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/user/anpadill@microsoft.com/event-hub/write-checkpoint
# Out[8]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7fe5f1f6aac0&gt;</div>
